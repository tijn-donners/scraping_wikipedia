# %% [markdown]
# # Mapping 17th century Dutch Painters with Folium
#
# Folium is a pythin library that uses leaflet.js in order to make interactive geographical visualizations. This notebook will guide you through the process of creating maps based on the data that was collected in the previous notebook.
#
# Make sure to install the folium library:

# %%
# !pip install folium #installs folium in your current env
# Out:
# Requirement already satisfied: folium in /home/tijn-do/anaconda3/lib/python3.12/site-packages (0.20.0)
# Requirement already satisfied: branca>=0.6.0 in /home/tijn-do/anaconda3/lib/python3.12/site-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in /home/tijn-do/anaconda3/lib/python3.12/site-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in /home/tijn-do/anaconda3/lib/python3.12/site-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in /home/tijn-do/anaconda3/lib/python3.12/site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /home/tijn-do/anaconda3/lib/python3.12/site-packages (from folium) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/tijn-do/anaconda3/lib/python3.12/site-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/tijn-do/anaconda3/lib/python3.12/site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/tijn-do/anaconda3/lib/python3.12/site-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/tijn-do/anaconda3/lib/python3.12/site-packages (from requests->folium) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/tijn-do/anaconda3/lib/python3.12/site-packages (from requests->folium) (2025.11.12)

# %% [markdown]
# #### First we import the required libraries and import the data

# %%
import folium as fo
import pandas as pd
from folium.plugins import AntPath

data = pd.read_csv('data.csv')
data.head(5)
# Out:
#                     Name Wikidata Identifier  \
# 0  Johannes van der Aeck            Q1033616
# 1        Evert van Aelst             Q759747
# 2       Willem van Aelst             Q553273
# 3           Jan van Aken            Q6150343
# 4  Herman van Aldewereld            Q1703946
#
#                                    Wikipedia Article Gender Year of Birth  \
# 0  Johannes Claesz. van der Aeck of Aack (gedoopt...   male          1636
# 1  Evert van Aelst (Delft, 1602 - aldaar, 19 febr...   male          1602
# 2  Willem van Aelst of Guillermo van Aelst (Delft...   male          1627
# 3  Jan van Aken, ook Jean van Aken (Amsterdam, ca...   male          1614
# 4  Herman van Aldewereld (1628/1629, Amsterdam – ...   male          1620
#
#   Year of Death Place of Birth Place of Death        Birth Coordinates  \
# 0          1682         Leiden         Leiden  (52.1594747, 4.4908843)
# 1          1657          Delft          Delft    (52.0114017, 4.35839)
# 2          1679          Delft      Amsterdam    (52.0114017, 4.35839)
# 3          1661         Kampen      Amsterdam  (52.5559484, 5.9033303)
# 4          1669      Amsterdam      Amsterdam  (52.3730796, 4.8924534)
#
#          Death Coordinates
# 0  (52.1594747, 4.4908843)
# 1    (52.0114017, 4.35839)
# 2  (52.3730796, 4.8924534)
# 3  (52.3730796, 4.8924534)
# 4  (52.3730796, 4.8924534)

# %% [markdown]
# #### Now we create a map using folium

# %%
m = fo.Map(location=(52.0907006, 5.1215634),  #Cooridnates of Utrecht, due to its centrality in the Netherlands
            tiles="cartodb positron", #for cosmetic purposes
            zoom_start=7) #set the zoom level. 7 seems to get the entire Nehterlands in frame

m  #shows the interactive map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c6f3ba306a641209a9b3a77f5f170e75 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c6f3ba306a641209a9b3a77f5f170e75&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c6f3ba306a641209a9b3a77f5f170e75 = L.map(
#                 &quot;map_c6f3ba306a641209a9b3a77f5f170e75&quot;,
#                 {
#                     center: [52.0907006, 5.1215634],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4beaedd89402c0ad2e46503f68aa8fe4 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4beaedd89402c0ad2e46503f68aa8fe4.addTo(map_c6f3ba306a641209a9b3a77f5f170e75);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Using AntPath for animated lines, we want to draw lines from birth to death place on the map
# Note that if either the birth or death coordinates are missing, the line will not be plotted.
# Painters that died in their birthplace are also left out.

# %%
for index, row in data.iterrows(): #loop through the rows of the DataFrame, variable row is a pd series
    
    if row['Birth Coordinates'] != 'na' and row['Death Coordinates'] != 'na' and row['Death Coordinates'] != row['Birth Coordinates']: #error handling for na values, and also filtering out incomplete entries
        
        birth = row['Birth Coordinates'].strip('()').split(', ') # split coords into a list
        death = row['Death Coordinates'].strip('()').split(', ') # split coords into a list

        birth = [float(coord) for coord in birth] # convert strings to floats
        death = [float(coord) for coord in death] # convert strings to floats

        line = [birth,death] #format for AntPath

        #create html for inside the popup with metadata from the DataFrame
        popup_text = f"""
            <p>Name: {row['Name']} ({row['Year of Birth']}-{row['Year of Death']})</p>
            <p>Place of Birth: {row['Place of Birth']}</p>
            <p>Place of Death: {row['Place of Death']}</p>
            <p>Gender: {row['Gender']}</p>
        """ 

        #create the antpath and plot it on the map
        fo.plugins.AntPath( 
            locations=line,
            weight=4,               # line thickness
            delay=500,              # animation speed (ms)
            dashArray=[10, 20],     # dashes
            popup=fo.Popup(popup_text, max_width=3000) # adds a popup when clicking on the antpath
        ).add_to(m)

        m.fit_bounds(m.get_bounds())

# %%
m.save("birth_death_path.html") #saves the map as html file
m #shows teh map in the notebook
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c6f3ba306a641209a9b3a77f5f170e75 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c6f3ba306a641209a9b3a77f5f170e75&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c6f3ba306a641209a9b3a77f5f170e75 = L.map(
#                 &quot;map_c6f3ba306a641209a9b3a77f5f170e75&quot;,
#                 {
#                     center: [52.0907006, 5.1215634],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4beaedd89402c0ad2e46503f68aa8fe4 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4beaedd89402c0ad2e46503f68aa8fe4.addTo(map_c6f3ba306a641209a9b3a77f5f170e75);
#
#
#             tile_layer_4beaedd89402c0ad2e46503f68aa8fe4.addTo(map_c6f3ba306a641209a9b3a77f5f170e75);
#
#
#             ant_path_8298223e1fcb39771131d859db8c7dbc = L.polyline.antPath(
#               [[52.0114017, 4.35839], [52.3730796, 4.8924534]],
#               {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#0000FF&quot;,
#   &quot;weight&quot;: 4,
#   &quot;opacity&quot;: 0.5,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: [
# 10,
# 20,
# ],
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: false,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;smoothFactor&quot;: 1.0,
#   &quot;noClip&quot;: false,
#   &quot;paused&quot;: false,
#   &quot;reverse&quot;: false,
#   &quot;hardwareAcceleration&quot;: false,
#   &quot;delay&quot;: 500,
#   &quot;pulseColor&quot;: &quot;#FFFFFF&quot;,
# }
#         ).addTo(map_c6f3ba306a641209a9b3a77f5f170e75);
#
#
#         var popup_9208fd21824a12a9970210a1a8d3f716 = L.popup({
#   &quot;maxWidth&quot;: 3000,
# });
#
#
#
#                 var html_8903ee21f45ed17a1d8427191eab2881 = $(`&lt;div id=&quot;html_8903ee21f45ed17a1d8427191eab2881&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;             &lt;p&gt;Name: Willem van Aelst (1627-1679)&lt;/p&gt;             &lt;p&gt;Place of Birth: Delft&lt;/p&gt;             &lt;p&gt;Place of Death: Amsterdam&lt;/p&gt;             &lt;p&gt;Gender: male&lt;/p&gt;         &lt;/div&gt;`)[0];
#                 popup_9208fd21824a12a9970210a1a8d3f716.setContent(html_8903ee21f45ed17a1d8427191eab2881);
#
#
#
#         ant_path_8298223e1fcb39771131d859db8c7dbc.bindPopup(popup_9208fd21824a12a9970210a1a8d3f716)
#         ;
#
#
#
#
#             map_c6f3ba306a641209a9b3a77f5f170e75.fitBounds(
#                 [[52.0114017, 4.35839], [52.3730796, 4.8924534]],
#                 {}
#             );
#
#
#             ant_path_667ea76d304cddbfd6802b874d39b1ca = L.polyline.antPath(
#               [[52.5559484, 5.9033303], [52.3730796, 4.8924534]],
#               {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#0000FF&quot;,
#   &quot;weight&quot;: 4,
#   &quot;opacity&quot;: 0.5,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: [
# 10,
# 20,
# ],
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: false,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;smoothFactor&quot;: 1.0,
#   &quot;noClip&quot;: false,
#   &quot;paused&quot;: false,
#   &quot;reverse&quot;: false,
#   &quot;hardwareAcceleration&quot;: false,
#   &quot;delay&quot;: 500,
#   &quot;pulseColor&quot;: &quot;#FFFFFF&quot;,
# }
#         ).addTo(map_c6f3ba306a641209a9b3a77f5f170e75);
#
#
#         var popup_0dc34a182f8d7d5a4a2fd40e5e9c9d0a = L.popup({
#   &quot;maxWidth&quot;: 3000,
# });
#
#
#
#                 var html_86a08aded9bc16fc817ca5232ac76945 = $(`&lt;div id=&quot;html_86a08aded9bc16fc817ca5232ac76945&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;             &lt;p&gt;Name: Jan van Aken (1614-1661)&lt;/p&gt;             &lt;p&gt;Place of Birth: Kampen&lt;/p&gt;             &lt;p&gt;Place of Death: Amsterdam&lt;/p&gt;             &lt;p&gt;Gender: male&lt;/p&gt;         &lt;/div&gt;`)[0];
#                 popup_0dc34a182f8d7d5a4a2fd40e5e9c9d0a.setContent(html_86a08aded9bc16fc817ca5232ac76945);

# %% [markdown]
# #### The map above shows the animted paths from birthplace towards place of death. When you click on a line you get a popup with biographical information about the painter.
#
# Some limitations about this view: if painters have the same birth and death place, they can't be distinguished on this map. Futhermore, there appear to some visual glitches when zooming in. In general it is quite cluttered, but it gives a in interesting overview.
#
# #### Let's visualize the birth places of the painters

# %%
#we overwrite m for a cleared map
m = fo.Map(location=(52.0907006, 5.1215634),  #Cooridnates of Utrecht, due to its centrality in the Netherlands
            tiles="cartodb positron", #cosmetics
            zoom_start=8) 

b_name_coords = data[['Place of Birth','Birth Coordinates']].copy()
                            
b_name_coords = pd.DataFrame(b_name_coords.value_counts()).reset_index()

b_name_coords.head()
# Out:
#   Place of Birth        Birth Coordinates  count
# 0      Amsterdam  (52.3730796, 4.8924534)     69
# 1        Haarlem  (52.3885317, 4.6388048)     62
# 2      The Hague  (52.0799838, 4.3113461)     32
# 3         Leiden  (52.1594747, 4.4908843)     29
# 4        Utrecht  (52.0907006, 5.1215634)     27

# %% [markdown]
# #### Now that we have counted the birthplaces, we want to plot them on the map. The more people that were born in a city, the larger the circle should be.

# %%
for index, row in b_name_coords.iterrows():
    if row['Place of Birth'] != 'na':
        # get the coords and convert them to floats
        birth = row['Birth Coordinates'].strip('()').split(', ') # split coords into a list
        birth = [float(coord) for coord in birth] # convert strings to floats

        #plot circles on the map
        fo.Circle(
                    location=birth,
                    radius= (row['count'])*70,  # by passing the count variable into this argument, the size of the circle adjutst to the number of painters per city
                    fill=True,  #colours in the circle
                    popup=fo.Popup(f'{row['Place of Birth']}: {row['count']}'),
                   ).add_to(m)

m.save('birthplaces.html') #save map as html
m #show map in output
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_42471cdc88d3567802f4a0b4f8f6b093 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_42471cdc88d3567802f4a0b4f8f6b093&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_42471cdc88d3567802f4a0b4f8f6b093 = L.map(
#                 &quot;map_42471cdc88d3567802f4a0b4f8f6b093&quot;,
#                 {
#                     center: [52.0907006, 5.1215634],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c1103af031a7df6cabb0a0b4ba81f77a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c1103af031a7df6cabb0a0b4ba81f77a.addTo(map_42471cdc88d3567802f4a0b4f8f6b093);
#
#
#             var circle_331c9ad5b91821fffb0ad170aac19903 = L.circle(
#                 [52.3730796, 4.8924534],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4830, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_42471cdc88d3567802f4a0b4f8f6b093);
#
#
#         var popup_0ff03529728d95ac0c3367b95f56a63c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b324b5e127345db46520d54f169412f4 = $(`&lt;div id=&quot;html_b324b5e127345db46520d54f169412f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Amsterdam: 69&lt;/div&gt;`)[0];
#                 popup_0ff03529728d95ac0c3367b95f56a63c.setContent(html_b324b5e127345db46520d54f169412f4);
#
#
#
#         circle_331c9ad5b91821fffb0ad170aac19903.bindPopup(popup_0ff03529728d95ac0c3367b95f56a63c)
#         ;
#
#
#
#
#             var circle_327f7f98f23b124b9ec28a24d926a1d9 = L.circle(
#                 [52.3885317, 4.6388048],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4340, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_42471cdc88d3567802f4a0b4f8f6b093);
#
#
#         var popup_0154a48ffb7511dfcc24942e3e535f6d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aed65adfb2a820a1a49e1b93d219a49f = $(`&lt;div id=&quot;html_aed65adfb2a820a1a49e1b93d219a49f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Haarlem: 62&lt;/div&gt;`)[0];
#                 popup_0154a48ffb7511dfcc24942e3e535f6d.setContent(html_aed65adfb2a820a1a49e1b93d219a49f);
#
#
#
#         circle_327f7f98f23b124b9ec28a24d926a1d9.bindPopup(popup_0154a48ffb7511dfcc24942e3e535f6d)
#         ;
#
#
#
#
#             var circle_0f95d57f2de8f35c869736e50066e5fc = L.circle(
#                 [52.0799838, 4.3113461],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2240, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_42471cdc88d3567802f4a0b4f8f6b093);
#
#
#         var popup_c4b03d1b7fdee9a48c69375017a17436 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9cf7c6202c1907b200149c4f40df54c3 = $(`&lt;div id=&quot;html_9cf7c6202c1907b200149c4f40df54c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The Hague: 32&lt;/div&gt;`)[0];
#                 popup_c4b03d1b7fdee9a48c69375017a17436.setContent(html_9cf7c6202c1907b200149c4f40df54c3);
#
#
#
#         circle_0f95d57f2de8f35c869736e50066e5fc.bindPopup(popup_c4b03d1b7fdee9a48c69375017a17436)
#         ;

# %% [markdown]
# You can click the circles to see the count/place name.
#
# #### Aswe can see, Amsterdam birthed the most painters, followed by Haarlem. Let's look at the places of death.

# %%
#we overwrite m for a cleared map
m = fo.Map(location=(52.0907006, 5.1215634),  #Cooridnates of Utrecht, due to its centrality in the Netherlands
            tiles="cartodb positron", #cosmetics
            zoom_start=8) 

d_name_coords = data[['Place of Death','Death Coordinates']].copy()
                            
d_name_coords = pd.DataFrame(d_name_coords.value_counts()).reset_index()

d_name_coords.head()
# Out:
#   Place of Death        Death Coordinates  count
# 0      Amsterdam  (52.3730796, 4.8924534)    127
# 1        Haarlem  (52.3837058, 4.6435597)     51
# 2      The Hague  (52.0749456, 4.2696802)     35
# 3        Utrecht  (52.0907006, 5.1215634)     29
# 4         Leiden  (52.1594747, 4.4908843)     18

# %%
for index, row in d_name_coords.iterrows():
    if row['Place of Death'] != 'na' and row['Death Coordinates']!= 'na':
        # get the coords and convert them to floats
        birth = row['Death Coordinates'].strip('()').split(', ') # split coords into a list
        birth = [float(coord) for coord in birth] # convert strings to floats

        #plot circles on the map
        fo.Circle(
                    location=birth,
                    radius= (row['count'])*70,  # by passing the count variable into this argument, the size of the circle adjutst to the number of painters per city
                    fill=True,  #colours in the circle
                    popup=fo.Popup(f'{row['Place of Death']}: {row['count']}'),
                   ).add_to(m)

m.save('deathplaces.html') #save map as html
m #show map in output
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_177fac543bd73a3ee364455acd72477d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_177fac543bd73a3ee364455acd72477d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_177fac543bd73a3ee364455acd72477d = L.map(
#                 &quot;map_177fac543bd73a3ee364455acd72477d&quot;,
#                 {
#                     center: [52.0907006, 5.1215634],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a6db59f5af9cb7a3108524622c81a104 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a6db59f5af9cb7a3108524622c81a104.addTo(map_177fac543bd73a3ee364455acd72477d);
#
#
#             var circle_9877380dc29c5a180550f178b122cb0d = L.circle(
#                 [52.3730796, 4.8924534],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8890, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_177fac543bd73a3ee364455acd72477d);
#
#
#         var popup_7af8e3e59ae46742ef58ff901613c13a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68a533e8d5b8e1560f1be749f77608c8 = $(`&lt;div id=&quot;html_68a533e8d5b8e1560f1be749f77608c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Amsterdam: 127&lt;/div&gt;`)[0];
#                 popup_7af8e3e59ae46742ef58ff901613c13a.setContent(html_68a533e8d5b8e1560f1be749f77608c8);
#
#
#
#         circle_9877380dc29c5a180550f178b122cb0d.bindPopup(popup_7af8e3e59ae46742ef58ff901613c13a)
#         ;
#
#
#
#
#             var circle_d6e66dd15e7a602166ab93ac2675445e = L.circle(
#                 [52.3837058, 4.6435597],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3570, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_177fac543bd73a3ee364455acd72477d);
#
#
#         var popup_0ae7985fb0d6297c44fa5720f9c7001b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2b08051b2ee6fedceeaf9300780296a = $(`&lt;div id=&quot;html_e2b08051b2ee6fedceeaf9300780296a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Haarlem: 51&lt;/div&gt;`)[0];
#                 popup_0ae7985fb0d6297c44fa5720f9c7001b.setContent(html_e2b08051b2ee6fedceeaf9300780296a);
#
#
#
#         circle_d6e66dd15e7a602166ab93ac2675445e.bindPopup(popup_0ae7985fb0d6297c44fa5720f9c7001b)
#         ;
#
#
#
#
#             var circle_366b940bc4483b6f2dc92f4b1a63b22e = L.circle(
#                 [52.0749456, 4.2696802],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2450, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_177fac543bd73a3ee364455acd72477d);
#
#
#         var popup_88f8c237c1de0c3b94aacd32be143e71 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_312f3db79d78ed6346578b4bdc6e9f55 = $(`&lt;div id=&quot;html_312f3db79d78ed6346578b4bdc6e9f55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The Hague: 35&lt;/div&gt;`)[0];
#                 popup_88f8c237c1de0c3b94aacd32be143e71.setContent(html_312f3db79d78ed6346578b4bdc6e9f55);
#
#
#
#         circle_366b940bc4483b6f2dc92f4b1a63b22e.bindPopup(popup_88f8c237c1de0c3b94aacd32be143e71)
#         ;

# %% [markdown]
# ### Conclusions based on the maps
#
# Amsterdam and Haarlem were, as is widely recognized by art historians, very central places for Dutch 'Golden Age' painters. 69 painters were born in Amsterdam and 62 in Haarlem. It seems likely that during the 17th century painters were attracted to Amsterdam, since 127 painters died in Amsterdam. These maps show that Haarlem had less deaths than births during the 17th century, suggesting a slight decrease in popularity.
#
# Interestingly, London and its surrounding areas have more deaths than births. This aligns with the historical notion that the center of artistic and economic prosperity shifted from Antwerp to Amsterdam, and finally to London in Early Modern Europe.
